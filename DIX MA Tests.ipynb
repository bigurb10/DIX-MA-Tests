# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
simple_returns_dict = dict()
exponential_returns_dict = dict()
output_to_csv1 = []
output_to_csv2 = []

# %%
#running the simple and exponential moving average tests
for i in range(2, 301):
    df = pd.read_csv('DIX.csv')
    df.columns = df.columns.str.strip()
    df['Pct Change'] = df['price'].pct_change()
    df['Simple Moving Average'] = df['dix'].rolling(window=i).mean().round(5)
    df['Exponential Moving Average'] = df['dix'].ewm(span=i,adjust=False).mean().round(5)
    df['Criteria'] = df['Simple Moving Average'] >= .4
    df['Criteria 2'] = df['Exponential Moving Average'] >= .4
    #actual model
    df['Buy and Hold'] = 100*(1+df['Pct Change']).cumprod()
    df['Simple Model'] = 100*(1+df['Criteria'].shift(1)*df['Pct Change']).cumprod()
    df['Exponential Model'] = 100*(1+df['Criteria 2'].shift(1)*df['Pct Change']).cumprod()
    #simple moving average model result
    simple_start_portfolio = df['Simple Model'].iloc[300]
    simple_end_portfolio = df['Simple Model'].iloc[-1]
    years = (df['Simple Model'].count()+1-300)/252
    simple_average_return = (simple_end_portfolio/simple_start_portfolio)**(1/years)-1
    simple_returns_dict[i] = simple_average_return
    print('This SIMPLE model yields an average of', simple_average_return, 'per year', 'using', i, 'days')
    output_to_csv1.append(('The ' + str(i) + ' sma',simple_average_return ))
    #exponential moving average model result
    exponential_start_portfolio = df['Exponential Model'].iloc[300]
    exponential_end_portfolio = df['Exponential Model'].iloc[-1]
    exponential_average_return = (exponential_end_portfolio/exponential_start_portfolio)**(1/years)-1
    exponential_returns_dict[i] = exponential_average_return
    print('This EXPONENTIAL model yields an average of', exponential_average_return, 'per year', 'using', i, 'days')
    output_to_csv2.append(('The ' + str(i) + ' ema',exponential_average_return ))
    #buy and hold the market result
    start_spx = df['price'].iloc[300]
    end_spx = df['price'].iloc[-1]
    spx_average_return = (end_spx/start_spx)**(1/years)-1
# Out:
# This SIMPLE model yields an average of 0.12378043465722843 per year using 2 days
# This EXPONENTIAL model yields an average of 0.12036803225671644 per year using 2 days
# This SIMPLE model yields an average of 0.13046141256683108 per year using 3 days
# This EXPONENTIAL model yields an average of 0.13388581480508788 per year using 3 days
# This SIMPLE model yields an average of 0.11397129926696836 per year using 4 days
# This EXPONENTIAL model yields an average of 0.10816379133428833 per year using 4 days
# This SIMPLE model yields an average of 0.09795867892284393 per year using 5 days
# This EXPONENTIAL model yields an average of 0.09325916122059885 per year using 5 days
# This SIMPLE model yields an average of 0.10335855353240242 per year using 6 days
# This EXPONENTIAL model yields an average of 0.1031732271393273 per year using 6 days
# This SIMPLE model yields an average of 0.10420846592860356 per year using 7 days
# This EXPONENTIAL model yields an average of 0.11679083007031266 per year using 7 days
# This SIMPLE model yields an average of 0.09657277756643778 per year using 8 days
# This EXPONENTIAL model yields an average of 0.11254466958554521 per year using 8 days
# This SIMPLE model yields an average of 0.0901414023930649 per year using 9 days
# This EXPONENTIAL model yields an average of 0.10786133432829348 per year using 9 days
# This SIMPLE model yields an average of 0.08527360604682777 per year using 10 days
# This EXPONENTIAL model yields an average of 0.10644920264880953 per year using 10 days
# This SIMPLE model yields an average of 0.08785034627255728 per year using 11 days
# This EXPONENTIAL model yields an average of 0.1055679869114603 per year using 11 days
# This SIMPLE model yields an average of 0.08611244391851058 per year using 12 days
# This EXPONENTIAL model yields an average of 0.0947333308839895 per year using 12 days
# This SIMPLE model yields an average of 0.08062115712467954 per year using 13 days
# This EXPONENTIAL model yields an average of 0.08153816557907323 per year using 13 days
# This SIMPLE model yields an average of 0.07388586105877981 per year using 14 days
# This EXPONENTIAL model yields an average of 0.09411012391404272 per year using 14 days
# This SIMPLE model yields an average of 0.09449557354523397 per year using 15 days
# This EXPONENTIAL model yields an average of 0.0929573111775639 per year using 15 days
# This SIMPLE model yields an average of 0.0853428069509583 per year using 16 days
# This EXPONENTIAL model yields an average of 0.0836458532793265 per year using 16 days
# This SIMPLE model yields an average of 0.08906701648464255 per year using 17 days
# This EXPONENTIAL model yields an average of 0.08540154803679467 per year using 17 days
# This SIMPLE model yields an average of 0.0866166544970648 per year using 18 days
# This EXPONENTIAL model yields an average of 0.0831736824470728 per year using 18 days
# This SIMPLE model yields an average of 0.07959154234037658 per year using 19 days
# This EXPONENTIAL model yields an average of 0.08700181075352087 per year using 19 days
# This SIMPLE model yields an average of 0.08620146877829482 per year using 20 days
# This EXPONENTIAL model yields an average of 0.0862887314888654 per year using 20 days
# This SIMPLE model yields an average of 0.07855074190586131 per year using 21 days
# This EXPONENTIAL model yields an average of 0.08431848510375994 per year using 21 days
# This SIMPLE model yields an average of 0.08979390562347 per year using 22 days
# This EXPONENTIAL model yields an average of 0.08410704146420289 per year using 22 days
# This SIMPLE model yields an average of 0.08360167311214961 per year using 23 days
# This EXPONENTIAL model yields an average of 0.08544028261792502 per year using 23 days
# This SIMPLE model yields an average of 0.07922192691882013 per year using 24 days
# This EXPONENTIAL model yields an average of 0.0827619535287869 per year using 24 days
# This SIMPLE model yields an average of 0.08498448831250638 per year using 25 days
# This EXPONENTIAL model yields an average of 0.07681926141452067 per year using 25 days
# This SIMPLE model yields an average of 0.08976138166713832 per year using 26 days
# This EXPONENTIAL model yields an average of 0.06980839462533561 per year using 26 days
# This SIMPLE model yields an average of 0.0813351608549151 per year using 27 days
# This EXPONENTIAL model yields an average of 0.06984799618848414 per year using 27 days
# This SIMPLE model yields an average of 0.08044138774954468 per year using 28 days
# This EXPONENTIAL model yields an average of 0.08133400347506892 per year using 28 days
# This SIMPLE model yields an average of 0.08467754870800359 per year using 29 days
# This EXPONENTIAL model yields an average of 0.0832807988827029 per year using 29 days
# This SIMPLE model yields an average of 0.08291662308489167 per year using 30 days
# This EXPONENTIAL model yields an average of 0.07396505014544896 per year using 30 days
# This SIMPLE model yields an average of 0.08423691993644278 per year using 31 days
# This EXPONENTIAL model yields an average of 0.07438996674118492 per year using 31 days
# This SIMPLE model yields an average of 0.08160657555678008 per year using 32 days
# This EXPONENTIAL model yields an average of 0.07635774277754948 per year using 32 days
# This SIMPLE model yields an average of 0.08191639752641255 per year using 33 days
# This EXPONENTIAL model yields an average of 0.07735004734759965 per year using 33 days
# This SIMPLE model yields an average of 0.08261668629205676 per year using 34 days
# This EXPONENTIAL model yields an average of 0.07793035837468754 per year using 34 days
# This SIMPLE model yields an average of 0.08471084232712522 per year using 35 days
# This EXPONENTIAL model yields an average of 0.08064122986935152 per year using 35 days
# This SIMPLE model yields an average of 0.08362800219908162 per year using 36 days
# This EXPONENTIAL model yields an average of 0.08220798947791108 per year using 36 days
# This SIMPLE model yields an average of 0.08297577168667236 per year using 37 days
# This EXPONENTIAL model yields an average of 0.08519328324886932 per year using 37 days
# This SIMPLE model yields an average of 0.07964012730411207 per year using 38 days
# This EXPONENTIAL model yields an average of 0.08377704592112734 per year using 38 days
# This SIMPLE model yields an average of 0.08443140125665183 per year using 39 days
# This EXPONENTIAL model yields an average of 0.08243513540790381 per year using 39 days
# This SIMPLE model yields an average of 0.07948079513108142 per year using 40 days
# This EXPONENTIAL model yields an average of 0.0845710073130983 per year using 40 days
# This SIMPLE model yields an average of 0.08492491773474042 per year using 41 days
# This EXPONENTIAL model yields an average of 0.08765908231793018 per year using 41 days
# This SIMPLE model yields an average of 0.08182347179742289 per year using 42 days
# This EXPONENTIAL model yields an average of 0.08765908231793018 per year using 42 days
# This SIMPLE model yields an average of 0.08444742675462846 per year using 43 days
# This EXPONENTIAL model yields an average of 0.0876014585144893 per year using 43 days
# This SIMPLE model yields an average of 0.08933934942567445 per year using 44 days
# This EXPONENTIAL model yields an average of 0.08739441232879863 per year using 44 days
# This SIMPLE model yields an average of 0.08659226815954102 per year using 45 days
# This EXPONENTIAL model yields an average of 0.08254236117422642 per year using 45 days
# This SIMPLE model yields an average of 0.08572428559877943 per year using 46 days
# This EXPONENTIAL model yields an average of 0.08137691257767599 per year using 46 days
# This SIMPLE model yields an average of 0.08218087122940032 per year using 47 days
# This EXPONENTIAL model yields an average of 0.08117905838176731 per year using 47 days
# This SIMPLE model yields an average of 0.08027441863831686 per year using 48 days
# This EXPONENTIAL model yields an average of 0.08342877643251145 per year using 48 days
# This SIMPLE model yields an average of 0.0815568966088489 per year using 49 days
# This EXPONENTIAL model yields an average of 0.08301694611941035 per year using 49 days
# This SIMPLE model yields an average of 0.08231666309056695 per year using 50 days
# This EXPONENTIAL model yields an average of 0.08598018534209295 per year using 50 days
# This SIMPLE model yields an average of 0.07775908066213177 per year using 51 days
# This EXPONENTIAL model yields an average of 0.08596012993523416 per year using 51 days
# This SIMPLE model yields an average of 0.07680761497687993 per year using 52 days
# This EXPONENTIAL model yields an average of 0.08511431069543685 per year using 52 days
# This SIMPLE model yields an average of 0.07543345930758738 per year using 53 days
# This EXPONENTIAL model yields an average of 0.08373372703688231 per year using 53 days
# This SIMPLE model yields an average of 0.07922589653464818 per year using 54 days
# This EXPONENTIAL model yields an average of 0.08392674020910551 per year using 54 days
# This SIMPLE model yields an average of 0.07655829417576854 per year using 55 days
# This EXPONENTIAL model yields an average of 0.07592069808575319 per year using 55 days
# This SIMPLE model yields an average of 0.07542203732225339 per year using 56 days
# This EXPONENTIAL model yields an average of 0.07548607348458569 per year using 56 days
# This SIMPLE model yields an average of 0.07831629201580892 per year using 57 days
# This EXPONENTIAL model yields an average of 0.0762463253909531 per year using 57 days
# This SIMPLE model yields an average of 0.07937782303563745 per year using 58 days
# This EXPONENTIAL model yields an average of 0.08177224804691607 per year using 58 days
# This SIMPLE model yields an average of 0.0775132715507394 per year using 59 days
# This EXPONENTIAL model yields an average of 0.08015356927829864 per year using 59 days
# This SIMPLE model yields an average of 0.0767660808477908 per year using 60 days
# This EXPONENTIAL model yields an average of 0.0800323596311936 per year using 60 days
# This SIMPLE model yields an average of 0.07900315682780823 per year using 61 days
# This EXPONENTIAL model yields an average of 0.08085172951530484 per year using 61 days
# This SIMPLE model yields an average of 0.07431318711456258 per year using 62 days
# This EXPONENTIAL model yields an average of 0.07751448833806673 per year using 62 days
# This SIMPLE model yields an average of 0.07291737198798143 per year using 63 days
# This EXPONENTIAL model yields an average of 0.07689300219987838 per year using 63 days
# This SIMPLE model yields an average of 0.07586182216123016 per year using 64 days
# This EXPONENTIAL model yields an average of 0.07689300219987838 per year using 64 days
# This SIMPLE model yields an average of 0.075966662042384 per year using 65 days
# This EXPONENTIAL model yields an average of 0.07788973112210851 per year using 65 days
# This SIMPLE model yields an average of 0.07250481823159105 per year using 66 days
# This EXPONENTIAL model yields an average of 0.07816114123761708 per year using 66 days
# This SIMPLE model yields an average of 0.07980781245040736 per year using 67 days
# This EXPONENTIAL model yields an average of 0.0815096042763499 per year using 67 days
# This SIMPLE model yields an average of 0.07824526253020925 per year using 68 days
# This EXPONENTIAL model yields an average of 0.08175028711872834 per year using 68 days
# This SIMPLE model yields an average of 0.07871819708132644 per year using 69 days
# This EXPONENTIAL model yields an average of 0.08247996124115686 per year using 69 days
# This SIMPLE model yields an average of 0.08292868968575062 per year using 70 days
# This EXPONENTIAL model yields an average of 0.07820952526013802 per year using 70 days
# This SIMPLE model yields an average of 0.0811825326660578 per year using 71 days
# This EXPONENTIAL model yields an average of 0.07950056258508686 per year using 71 days
# This SIMPLE model yields an average of 0.08144653957882841 per year using 72 days
# This EXPONENTIAL model yields an average of 0.07981935779104687 per year using 72 days
# This SIMPLE model yields an average of 0.080002198627116 per year using 73 days
# This EXPONENTIAL model yields an average of 0.08302651073938949 per year using 73 days
# This SIMPLE model yields an average of 0.07949494613875285 per year using 74 days
# This EXPONENTIAL model yields an average of 0.08366066591053944 per year using 74 days
# This SIMPLE model yields an average of 0.07799746982110611 per year using 75 days
# This EXPONENTIAL model yields an average of 0.08176662559427306 per year using 75 days
# This SIMPLE model yields an average of 0.0746626908707475 per year using 76 days
# This EXPONENTIAL model yields an average of 0.08352034684168519 per year using 76 days
# This SIMPLE model yields an average of 0.07457922311135068 per year using 77 days
# This EXPONENTIAL model yields an average of 0.08565648653233127 per year using 77 days
# This SIMPLE model yields an average of 0.07584856932847406 per year using 78 days
# This EXPONENTIAL model yields an average of 0.08643866995950944 per year using 78 days
# This SIMPLE model yields an average of 0.07607680107946235 per year using 79 days
# This EXPONENTIAL model yields an average of 0.08643866995950944 per year using 79 days
# This SIMPLE model yields an average of 0.0774053524772167 per year using 80 days
# This EXPONENTIAL model yields an average of 0.0854978628241343 per year using 80 days
# This SIMPLE model yields an average of 0.07923420635812128 per year using 81 days
# This EXPONENTIAL model yields an average of 0.08571579357755832 per year using 81 days
# This SIMPLE model yields an average of 0.08122292523958174 per year using 82 days
# This EXPONENTIAL model yields an average of 0.08725632174304598 per year using 82 days
# This SIMPLE model yields an average of 0.08184355951191757 per year using 83 days
# This EXPONENTIAL model yields an average of 0.0879876671606803 per year using 83 days
# This SIMPLE model yields an average of 0.07791245165042993 per year using 84 days
# This EXPONENTIAL model yields an average of 0.08673809185772074 per year using 84 days
# This SIMPLE model yields an average of 0.07885007710199066 per year using 85 days
# This EXPONENTIAL model yields an average of 0.08772009056600538 per year using 85 days
# This SIMPLE model yields an average of 0.08130031008073946 per year using 86 days
# This EXPONENTIAL model yields an average of 0.08781841049486361 per year using 86 days
# This SIMPLE model yields an average of 0.08253042122439558 per year using 87 days
# This EXPONENTIAL model yields an average of 0.08737752205304283 per year using 87 days
# This SIMPLE model yields an average of 0.08798759076233398 per year using 88 days
# This EXPONENTIAL model yields an average of 0.08670509272904603 per year using 88 days
# This SIMPLE model yields an average of 0.08767649433390723 per year using 89 days
# This EXPONENTIAL model yields an average of 0.08674749093018419 per year using 89 days
# This SIMPLE model yields an average of 0.08202558486772538 per year using 90 days
# This EXPONENTIAL model yields an average of 0.08624531355447407 per year using 90 days
# This SIMPLE model yields an average of 0.08576223327721189 per year using 91 days
# This EXPONENTIAL model yields an average of 0.08477923063628623 per year using 91 days
# This SIMPLE model yields an average of 0.08560582893830482 per year using 92 days
# This EXPONENTIAL model yields an average of 0.08617211485013021 per year using 92 days
# This SIMPLE model yields an average of 0.0838411040224818 per year using 93 days
# This EXPONENTIAL model yields an average of 0.0870734768842234 per year using 93 days
# This SIMPLE model yields an average of 0.08351118905959942 per year using 94 days
# This EXPONENTIAL model yields an average of 0.08830608762502035 per year using 94 days
# This SIMPLE model yields an average of 0.08175437997851298 per year using 95 days
# This EXPONENTIAL model yields an average of 0.09072867700088505 per year using 95 days
# This SIMPLE model yields an average of 0.080534456164711 per year using 96 days
# This EXPONENTIAL model yields an average of 0.09072867700088505 per year using 96 days
# This SIMPLE model yields an average of 0.07918207315825598 per year using 97 days
# This EXPONENTIAL model yields an average of 0.08972319828209963 per year using 97 days
# This SIMPLE model yields an average of 0.07665651804668516 per year using 98 days
# This EXPONENTIAL model yields an average of 0.08975167247170379 per year using 98 days
# This SIMPLE model yields an average of 0.07581999815188567 per year using 99 days
# This EXPONENTIAL model yields an average of 0.09156007870084104 per year using 99 days
# This SIMPLE model yields an average of 0.07564980613003702 per year using 100 days
# This EXPONENTIAL model yields an average of 0.0918028590842479 per year using 100 days
# This SIMPLE model yields an average of 0.07490434977279259 per year using 101 days
# This EXPONENTIAL model yields an average of 0.09573863952284012 per year using 101 days
# This SIMPLE model yields an average of 0.07589096047481902 per year using 102 days
# This EXPONENTIAL model yields an average of 0.09571487247577815 per year using 102 days
# This SIMPLE model yields an average of 0.07485785634279885 per year using 103 days
# This EXPONENTIAL model yields an average of 0.09941547107312987 per year using 103 days
# This SIMPLE model yields an average of 0.07375072834857477 per year using 104 days
# This EXPONENTIAL model yields an average of 0.10086864193164735 per year using 104 days
# This SIMPLE model yields an average of 0.0743318219335305 per year using 105 days
# This EXPONENTIAL model yields an average of 0.10079038315514177 per year using 105 days
# This SIMPLE model yields an average of 0.07424507063933716 per year using 106 days
# This EXPONENTIAL model yields an average of 0.0989604988530397 per year using 106 days
# This SIMPLE model yields an average of 0.07163356121411568 per year using 107 days
# This EXPONENTIAL model yields an average of 0.09886022938552164 per year using 107 days
# This SIMPLE model yields an average of 0.07325585193682627 per year using 108 days
# This EXPONENTIAL model yields an average of 0.09886022938552164 per year using 108 days
# This SIMPLE model yields an average of 0.0764773996611341 per year using 109 days
# This EXPONENTIAL model yields an average of 0.09910401114250256 per year using 109 days
# This SIMPLE model yields an average of 0.07912357188565777 per year using 110 days
# This EXPONENTIAL model yields an average of 0.10007805601923181 per year using 110 days
# This SIMPLE model yields an average of 0.07771665591614996 per year using 111 days
# This EXPONENTIAL model yields an average of 0.10085320406208176 per year using 111 days
# This SIMPLE model yields an average of 0.07688279429675582 per year using 112 days
# This EXPONENTIAL model yields an average of 0.10132522258861298 per year using 112 days
# This SIMPLE model yields an average of 0.07814731353192483 per year using 113 days
# This EXPONENTIAL model yields an average of 0.10132522258861298 per year using 113 days
# This SIMPLE model yields an average of 0.08188562288797696 per year using 114 days
# This EXPONENTIAL model yields an average of 0.10014643055841321 per year using 114 days
# This SIMPLE model yields an average of 0.08328491938775073 per year using 115 days
# This EXPONENTIAL model yields an average of 0.10014643055841321 per year using 115 days
# This SIMPLE model yields an average of 0.08673321041983706 per year using 116 days
# This EXPONENTIAL model yields an average of 0.10014643055841321 per year using 116 days
# This SIMPLE model yields an average of 0.08529061480835765 per year using 117 days
# This EXPONENTIAL model yields an average of 0.1000940609681531 per year using 117 days
# This SIMPLE model yields an average of 0.08844376424047695 per year using 118 days
# This EXPONENTIAL model yields an average of 0.09838169856240975 per year using 118 days
# This SIMPLE model yields an average of 0.08753719377670333 per year using 119 days
# This EXPONENTIAL model yields an average of 0.09838169856240975 per year using 119 days
# This SIMPLE model yields an average of 0.08662938509744333 per year using 120 days
# This EXPONENTIAL model yields an average of 0.09838169856241019 per year using 120 days
# This SIMPLE model yields an average of 0.0850060392696359 per year using 121 days
# This EXPONENTIAL model yields an average of 0.09648007693312333 per year using 121 days
# This SIMPLE model yields an average of 0.0822383282362602 per year using 122 days
# This EXPONENTIAL model yields an average of 0.09763364808979946 per year using 122 days
# This SIMPLE model yields an average of 0.08566974798213067 per year using 123 days
# This EXPONENTIAL model yields an average of 0.09763364808979946 per year using 123 days
# This SIMPLE model yields an average of 0.08529951870564134 per year using 124 days
# This EXPONENTIAL model yields an average of 0.09707757662050298 per year using 124 days
# This SIMPLE model yields an average of 0.08612035401091678 per year using 125 days
# This EXPONENTIAL model yields an average of 0.0970775766205032 per year using 125 days
# This SIMPLE model yields an average of 0.0889590263709219 per year using 126 days
# This EXPONENTIAL model yields an average of 0.0970775766205032 per year using 126 days
# This SIMPLE model yields an average of 0.0848903445757514 per year using 127 days
# This EXPONENTIAL model yields an average of 0.09678889315537598 per year using 127 days
# This SIMPLE model yields an average of 0.08314495637049402 per year using 128 days
# This EXPONENTIAL model yields an average of 0.09578928617315641 per year using 128 days
# This SIMPLE model yields an average of 0.08193776962103305 per year using 129 days
# This EXPONENTIAL model yields an average of 0.09633118377354943 per year using 129 days
# This SIMPLE model yields an average of 0.08193318885155887 per year using 130 days
# This EXPONENTIAL model yields an average of 0.09633118377354943 per year using 130 days
# This SIMPLE model yields an average of 0.07679105415642429 per year using 131 days
# This EXPONENTIAL model yields an average of 0.09633118377354943 per year using 131 days
# This SIMPLE model yields an average of 0.07807990544474896 per year using 132 days
# This EXPONENTIAL model yields an average of 0.09633118377354988 per year using 132 days
# This SIMPLE model yields an average of 0.07869199361672607 per year using 133 days
# This EXPONENTIAL model yields an average of 0.09633118377354988 per year using 133 days
# This SIMPLE model yields an average of 0.07624676123704432 per year using 134 days
# This EXPONENTIAL model yields an average of 0.09580348017777762 per year using 134 days
# This SIMPLE model yields an average of 0.07969966142688256 per year using 135 days
# This EXPONENTIAL model yields an average of 0.09580348017777762 per year using 135 days
# This SIMPLE model yields an average of 0.07979859802958855 per year using 136 days
# This EXPONENTIAL model yields an average of 0.09645815685251957 per year using 136 days
# This SIMPLE model yields an average of 0.07910232297838427 per year using 137 days
# This EXPONENTIAL model yields an average of 0.09645815685251957 per year using 137 days
# This SIMPLE model yields an average of 0.07910230036536925 per year using 138 days
# This EXPONENTIAL model yields an average of 0.09644203169590071 per year using 138 days
# This SIMPLE model yields an average of 0.08067427141086059 per year using 139 days
# This EXPONENTIAL model yields an average of 0.09644203169590071 per year using 139 days
# This SIMPLE model yields an average of 0.08200129067835804 per year using 140 days
# This EXPONENTIAL model yields an average of 0.09644203169590071 per year using 140 days
# This SIMPLE model yields an average of 0.0822060003689733 per year using 141 days
# This EXPONENTIAL model yields an average of 0.09685647662645369 per year using 141 days
# This SIMPLE model yields an average of 0.07919998337124068 per year using 142 days
# This EXPONENTIAL model yields an average of 0.09627135109296603 per year using 142 days
# This SIMPLE model yields an average of 0.07990613523356904 per year using 143 days
# This EXPONENTIAL model yields an average of 0.09627135109296603 per year using 143 days
# This SIMPLE model yields an average of 0.08135965040871596 per year using 144 days
# This EXPONENTIAL model yields an average of 0.09714193031596752 per year using 144 days
# This SIMPLE model yields an average of 0.08201687558152848 per year using 145 days
# This EXPONENTIAL model yields an average of 0.09791824357877643 per year using 145 days
# This SIMPLE model yields an average of 0.08100601916157246 per year using 146 days
# This EXPONENTIAL model yields an average of 0.09791824357877643 per year using 146 days
# This SIMPLE model yields an average of 0.08098419119432831 per year using 147 days
# This EXPONENTIAL model yields an average of 0.09999575706644959 per year using 147 days
# This SIMPLE model yields an average of 0.0816541917837823 per year using 148 days
# This EXPONENTIAL model yields an average of 0.10020418527538233 per year using 148 days
# This SIMPLE model yields an average of 0.0816946340076603 per year using 149 days
# This EXPONENTIAL model yields an average of 0.09938542315258414 per year using 149 days
# This SIMPLE model yields an average of 0.08258333958436737 per year using 150 days
# This EXPONENTIAL model yields an average of 0.09938542315258458 per year using 150 days
# This SIMPLE model yields an average of 0.08459144547156461 per year using 151 days
# This EXPONENTIAL model yields an average of 0.10007036459744811 per year using 151 days
# This SIMPLE model yields an average of 0.08612398227328111 per year using 152 days
# This EXPONENTIAL model yields an average of 0.10007036459744767 per year using 152 days
# This SIMPLE model yields an average of 0.08541563298969868 per year using 153 days
# This EXPONENTIAL model yields an average of 0.10029091119592914 per year using 153 days
# This SIMPLE model yields an average of 0.08376102818285025 per year using 154 days
# This EXPONENTIAL model yields an average of 0.1005387486441578 per year using 154 days
# This SIMPLE model yields an average of 0.08509641622223962 per year using 155 days
# This EXPONENTIAL model yields an average of 0.1005387486441578 per year using 155 days
# This SIMPLE model yields an average of 0.08433953839044372 per year using 156 days
# This EXPONENTIAL model yields an average of 0.1005387486441578 per year using 156 days
# This SIMPLE model yields an average of 0.08546879386620221 per year using 157 days
# This EXPONENTIAL model yields an average of 0.10019680889423555 per year using 157 days
# This SIMPLE model yields an average of 0.08391492386701316 per year using 158 days
# This EXPONENTIAL model yields an average of 0.10019680889423555 per year using 158 days
# This SIMPLE model yields an average of 0.0857067286794968 per year using 159 days
# This EXPONENTIAL model yields an average of 0.10019680889423532 per year using 159 days
# This SIMPLE model yields an average of 0.0858280294390592 per year using 160 days
# This EXPONENTIAL model yields an average of 0.1007915011860836 per year using 160 days
# This SIMPLE model yields an average of 0.08721970539689572 per year using 161 days
# This EXPONENTIAL model yields an average of 0.09988614495406045 per year using 161 days
# This SIMPLE model yields an average of 0.08755189084101334 per year using 162 days
# This EXPONENTIAL model yields an average of 0.10059576374243684 per year using 162 days
# This SIMPLE model yields an average of 0.0893755810630783 per year using 163 days
# This EXPONENTIAL model yields an average of 0.10204555077551647 per year using 163 days
# This SIMPLE model yields an average of 0.08592161099599704 per year using 164 days
# This EXPONENTIAL model yields an average of 0.10035575128861951 per year using 164 days
# This SIMPLE model yields an average of 0.08306980877189085 per year using 165 days
# This EXPONENTIAL model yields an average of 0.10287039423228572 per year using 165 days
# This SIMPLE model yields an average of 0.08597328008975458 per year using 166 days
# This EXPONENTIAL model yields an average of 0.10320883466061703 per year using 166 days
# This SIMPLE model yields an average of 0.08616165974987489 per year using 167 days
# This EXPONENTIAL model yields an average of 0.10320883466061703 per year using 167 days
# This SIMPLE model yields an average of 0.08857437489303521 per year using 168 days
# This EXPONENTIAL model yields an average of 0.10320883466061703 per year using 168 days
# This SIMPLE model yields an average of 0.08739835578233701 per year using 169 days
# This EXPONENTIAL model yields an average of 0.10422764258169681 per year using 169 days
# This SIMPLE model yields an average of 0.08986587393753687 per year using 170 days
# This EXPONENTIAL model yields an average of 0.10422764258169681 per year using 170 days
# This SIMPLE model yields an average of 0.08986676465114374 per year using 171 days
# This EXPONENTIAL model yields an average of 0.10422764258169681 per year using 171 days
# This SIMPLE model yields an average of 0.08922473800410202 per year using 172 days
# This EXPONENTIAL model yields an average of 0.10422764258169681 per year using 172 days
# This SIMPLE model yields an average of 0.08745067179918475 per year using 173 days
# This EXPONENTIAL model yields an average of 0.10376403695242553 per year using 173 days
# This SIMPLE model yields an average of 0.08614028525450146 per year using 174 days
# This EXPONENTIAL model yields an average of 0.10203498403582256 per year using 174 days
# This SIMPLE model yields an average of 0.08768429100675235 per year using 175 days
# This EXPONENTIAL model yields an average of 0.10203498403582256 per year using 175 days
# This SIMPLE model yields an average of 0.08809852839334842 per year using 176 days
# This EXPONENTIAL model yields an average of 0.10203498403582256 per year using 176 days
# This SIMPLE model yields an average of 0.09151023008041359 per year using 177 days
# This EXPONENTIAL model yields an average of 0.10226335630926964 per year using 177 days
# This SIMPLE model yields an average of 0.09256424184951606 per year using 178 days
# This EXPONENTIAL model yields an average of 0.10226335630926897 per year using 178 days
# This SIMPLE model yields an average of 0.09119443046618758 per year using 179 days
# This EXPONENTIAL model yields an average of 0.09900136833344164 per year using 179 days
# This SIMPLE model yields an average of 0.09295947861902931 per year using 180 days
# This EXPONENTIAL model yields an average of 0.09907050651294025 per year using 180 days
# This SIMPLE model yields an average of 0.09512180230887513 per year using 181 days
# This EXPONENTIAL model yields an average of 0.0993526244161782 per year using 181 days
# This SIMPLE model yields an average of 0.09506066935875657 per year using 182 days
# This EXPONENTIAL model yields an average of 0.0996451508655174 per year using 182 days
# This SIMPLE model yields an average of 0.09837666586758176 per year using 183 days
# This EXPONENTIAL model yields an average of 0.0996451508655174 per year using 183 days
# This SIMPLE model yields an average of 0.09967285236798085 per year using 184 days
# This EXPONENTIAL model yields an average of 0.0995801947316679 per year using 184 days
# This SIMPLE model yields an average of 0.09779789078130707 per year using 185 days
# This EXPONENTIAL model yields an average of 0.0995400462691085 per year using 185 days
# This SIMPLE model yields an average of 0.0987188487161692 per year using 186 days
# This EXPONENTIAL model yields an average of 0.10050876205185255 per year using 186 days
# This SIMPLE model yields an average of 0.09784992539154658 per year using 187 days
# This EXPONENTIAL model yields an average of 0.10050876205185255 per year using 187 days
# This SIMPLE model yields an average of 0.10025091306722311 per year using 188 days
# This EXPONENTIAL model yields an average of 0.09981942439624536 per year using 188 days
# This SIMPLE model yields an average of 0.10018348524116294 per year using 189 days
# This EXPONENTIAL model yields an average of 0.10007922352098686 per year using 189 days
# This SIMPLE model yields an average of 0.10043130927292121 per year using 190 days
# This EXPONENTIAL model yields an average of 0.1000792235209873 per year using 190 days
# This SIMPLE model yields an average of 0.09971914278371696 per year using 191 days
# This EXPONENTIAL model yields an average of 0.09914556981478984 per year using 191 days
# This SIMPLE model yields an average of 0.10188523086530821 per year using 192 days
# This EXPONENTIAL model yields an average of 0.10010691969429764 per year using 192 days
# This SIMPLE model yields an average of 0.10339805482822673 per year using 193 days
# This EXPONENTIAL model yields an average of 0.10195961543098409 per year using 193 days
# This SIMPLE model yields an average of 0.10283122632079311 per year using 194 days
# This EXPONENTIAL model yields an average of 0.10195961543098409 per year using 194 days
# This SIMPLE model yields an average of 0.10317080209860707 per year using 195 days
# This EXPONENTIAL model yields an average of 0.10195961543098409 per year using 195 days
# This SIMPLE model yields an average of 0.10178938670093496 per year using 196 days
# This EXPONENTIAL model yields an average of 0.10286705368554516 per year using 196 days
# This SIMPLE model yields an average of 0.10017525452633658 per year using 197 days
# This EXPONENTIAL model yields an average of 0.10286705368554516 per year using 197 days
# This SIMPLE model yields an average of 0.10340878667721554 per year using 198 days
# This EXPONENTIAL model yields an average of 0.10286705368554516 per year using 198 days
# This SIMPLE model yields an average of 0.0980641438756884 per year using 199 days
# This EXPONENTIAL model yields an average of 0.10560507500966843 per year using 199 days
# This SIMPLE model yields an average of 0.09280296215613149 per year using 200 days
# This EXPONENTIAL model yields an average of 0.10679616744165532 per year using 200 days
# This SIMPLE model yields an average of 0.09050170162765747 per year using 201 days
# This EXPONENTIAL model yields an average of 0.10686038656284191 per year using 201 days
# This SIMPLE model yields an average of 0.09174205753915743 per year using 202 days
# This EXPONENTIAL model yields an average of 0.10785254411954259 per year using 202 days
# This SIMPLE model yields an average of 0.08627405138608801 per year using 203 days
# This EXPONENTIAL model yields an average of 0.10785247787523344 per year using 203 days
# This SIMPLE model yields an average of 0.08659259122689367 per year using 204 days
# This EXPONENTIAL model yields an average of 0.1080969824789948 per year using 204 days
# This SIMPLE model yields an average of 0.08613190012656502 per year using 205 days
# This EXPONENTIAL model yields an average of 0.1078630476229605 per year using 205 days
# This SIMPLE model yields an average of 0.08915266831133484 per year using 206 days
# This EXPONENTIAL model yields an average of 0.1080510802430028 per year using 206 days
# This SIMPLE model yields an average of 0.08540620698491441 per year using 207 days
# This EXPONENTIAL model yields an average of 0.1080510802430028 per year using 207 days
# This SIMPLE model yields an average of 0.09017384330282652 per year using 208 days
# This EXPONENTIAL model yields an average of 0.10789111037708965 per year using 208 days
# This SIMPLE model yields an average of 0.09156545511069569 per year using 209 days
# This EXPONENTIAL model yields an average of 0.10273345605627804 per year using 209 days
# This SIMPLE model yields an average of 0.09344480403554267 per year using 210 days
# This EXPONENTIAL model yields an average of 0.10308527937131573 per year using 210 days
# This SIMPLE model yields an average of 0.09305860392219767 per year using 211 days
# This EXPONENTIAL model yields an average of 0.10471672987794634 per year using 211 days
# This SIMPLE model yields an average of 0.09260982916778371 per year using 212 days
# This EXPONENTIAL model yields an average of 0.10631363337693611 per year using 212 days
# This SIMPLE model yields an average of 0.09341070714775723 per year using 213 days
# This EXPONENTIAL model yields an average of 0.10727283146890199 per year using 213 days
# This SIMPLE model yields an average of 0.09345862173988717 per year using 214 days
# This EXPONENTIAL model yields an average of 0.10808684600258234 per year using 214 days
# This SIMPLE model yields an average of 0.09796964983896572 per year using 215 days
# This EXPONENTIAL model yields an average of 0.10826804148239066 per year using 215 days
# This SIMPLE model yields an average of 0.10207609391365113 per year using 216 days
# This EXPONENTIAL model yields an average of 0.10718762105957769 per year using 216 days
# This SIMPLE model yields an average of 0.09754259417106681 per year using 217 days
# This EXPONENTIAL model yields an average of 0.10852582183032888 per year using 217 days
# This SIMPLE model yields an average of 0.09454287199197009 per year using 218 days
# This EXPONENTIAL model yields an average of 0.1091321868027797 per year using 218 days
# This SIMPLE model yields an average of 0.0943773568461661 per year using 219 days
# This EXPONENTIAL model yields an average of 0.1091321868027797 per year using 219 days
# This SIMPLE model yields an average of 0.09459016648483942 per year using 220 days
# This EXPONENTIAL model yields an average of 0.10774160322251669 per year using 220 days
# This SIMPLE model yields an average of 0.09451374411460334 per year using 221 days
# This EXPONENTIAL model yields an average of 0.10751268154779803 per year using 221 days
# This SIMPLE model yields an average of 0.09334853947736921 per year using 222 days
# This EXPONENTIAL model yields an average of 0.10766266383760925 per year using 222 days
# This SIMPLE model yields an average of 0.09536837675077003 per year using 223 days
# This EXPONENTIAL model yields an average of 0.10766266383760925 per year using 223 days
# This SIMPLE model yields an average of 0.10183571713856177 per year using 224 days
# This EXPONENTIAL model yields an average of 0.10766266383760925 per year using 224 days
# This SIMPLE model yields an average of 0.10319382968086321 per year using 225 days
# This EXPONENTIAL model yields an average of 0.1057981941236521 per year using 225 days
# This SIMPLE model yields an average of 0.10075329314838699 per year using 226 days
# This EXPONENTIAL model yields an average of 0.1057981941236521 per year using 226 days
# This SIMPLE model yields an average of 0.09909233289120079 per year using 227 days
# This EXPONENTIAL model yields an average of 0.1057981941236521 per year using 227 days
# This SIMPLE model yields an average of 0.09707997518059441 per year using 228 days
# This EXPONENTIAL model yields an average of 0.10694449858871269 per year using 228 days
# This SIMPLE model yields an average of 0.09143974342653682 per year using 229 days
# This EXPONENTIAL model yields an average of 0.11077492173112669 per year using 229 days
# This SIMPLE model yields an average of 0.09162234563544214 per year using 230 days
# This EXPONENTIAL model yields an average of 0.11077492173112669 per year using 230 days
# This SIMPLE model yields an average of 0.09435529037488144 per year using 231 days
# This EXPONENTIAL model yields an average of 0.11077492173112669 per year using 231 days
# This SIMPLE model yields an average of 0.09759908607892664 per year using 232 days
# This EXPONENTIAL model yields an average of 0.11078207867250134 per year using 232 days
# This SIMPLE model yields an average of 0.09155166358477262 per year using 233 days
# This EXPONENTIAL model yields an average of 0.10775116423428033 per year using 233 days
# This SIMPLE model yields an average of 0.09058353494049531 per year using 234 days
# This EXPONENTIAL model yields an average of 0.10806436979549594 per year using 234 days
# This SIMPLE model yields an average of 0.08825175387535467 per year using 235 days
# This EXPONENTIAL model yields an average of 0.10806436979549594 per year using 235 days
# This SIMPLE model yields an average of 0.08767731981510996 per year using 236 days
# This EXPONENTIAL model yields an average of 0.10443140416131147 per year using 236 days
# This SIMPLE model yields an average of 0.08653761324941711 per year using 237 days
# This EXPONENTIAL model yields an average of 0.10419065006041306 per year using 237 days
# This SIMPLE model yields an average of 0.08626066403337918 per year using 238 days
# This EXPONENTIAL model yields an average of 0.10411092286858148 per year using 238 days
# This SIMPLE model yields an average of 0.08626066403337895 per year using 239 days
# This EXPONENTIAL model yields an average of 0.1040579297225197 per year using 239 days
# This SIMPLE model yields an average of 0.08564595493168636 per year using 240 days
# This EXPONENTIAL model yields an average of 0.1040579297225197 per year using 240 days
# This SIMPLE model yields an average of 0.08743892015374444 per year using 241 days
# This EXPONENTIAL model yields an average of 0.1040579297225197 per year using 241 days
# This SIMPLE model yields an average of 0.0914392438206939 per year using 242 days
# This EXPONENTIAL model yields an average of 0.10414216456795211 per year using 242 days
# This SIMPLE model yields an average of 0.09049535756595017 per year using 243 days
# This EXPONENTIAL model yields an average of 0.10211983028801286 per year using 243 days
# This SIMPLE model yields an average of 0.09050299941682693 per year using 244 days
# This EXPONENTIAL model yields an average of 0.10235029251371497 per year using 244 days
# This SIMPLE model yields an average of 0.0932132428830943 per year using 245 days
# This EXPONENTIAL model yields an average of 0.10270867172142539 per year using 245 days
# This SIMPLE model yields an average of 0.0950951906214339 per year using 246 days
# This EXPONENTIAL model yields an average of 0.10437817714079389 per year using 246 days
# This SIMPLE model yields an average of 0.09515026567354523 per year using 247 days
# This EXPONENTIAL model yields an average of 0.10437817714079389 per year using 247 days
# This SIMPLE model yields an average of 0.09793484543604314 per year using 248 days
# This EXPONENTIAL model yields an average of 0.10437817714079367 per year using 248 days
# This SIMPLE model yields an average of 0.0979348454360438 per year using 249 days
# This EXPONENTIAL model yields an average of 0.10430070843191541 per year using 249 days
# This SIMPLE model yields an average of 0.09843819706931711 per year using 250 days
# This EXPONENTIAL model yields an average of 0.1033750224966985 per year using 250 days
# This SIMPLE model yields an average of 0.10009080731631692 per year using 251 days
# This EXPONENTIAL model yields an average of 0.1033750224966985 per year using 251 days
# This SIMPLE model yields an average of 0.1000908073163167 per year using 252 days
# This EXPONENTIAL model yields an average of 0.10241671890761972 per year using 252 days
# This SIMPLE model yields an average of 0.10007394310546514 per year using 253 days
# This EXPONENTIAL model yields an average of 0.10241671890761972 per year using 253 days
# This SIMPLE model yields an average of 0.09909424559458846 per year using 254 days
# This EXPONENTIAL model yields an average of 0.10150890126621848 per year using 254 days
# This SIMPLE model yields an average of 0.09869283692186803 per year using 255 days
# This EXPONENTIAL model yields an average of 0.10150890126621848 per year using 255 days
# This SIMPLE model yields an average of 0.09869283692186759 per year using 256 days
# This EXPONENTIAL model yields an average of 0.10066949233794809 per year using 256 days
# This SIMPLE model yields an average of 0.09873646726788898 per year using 257 days
# This EXPONENTIAL model yields an average of 0.10339784362716875 per year using 257 days
# This SIMPLE model yields an average of 0.09873646726788898 per year using 258 days
# This EXPONENTIAL model yields an average of 0.10384837577494377 per year using 258 days
# This SIMPLE model yields an average of 0.09913789188100686 per year using 259 days
# This EXPONENTIAL model yields an average of 0.10384837577494377 per year using 259 days
# This SIMPLE model yields an average of 0.09873646726788943 per year using 260 days
# This EXPONENTIAL model yields an average of 0.10385129987988595 per year using 260 days
# This SIMPLE model yields an average of 0.09873646726788965 per year using 261 days
# This EXPONENTIAL model yields an average of 0.10385814412258565 per year using 261 days
# This SIMPLE model yields an average of 0.0987364672678892 per year using 262 days
# This EXPONENTIAL model yields an average of 0.1039380553999949 per year using 262 days
# This SIMPLE model yields an average of 0.09954181648832128 per year using 263 days
# This EXPONENTIAL model yields an average of 0.10814811885044429 per year using 263 days
# This SIMPLE model yields an average of 0.09954181648832039 per year using 264 days
# This EXPONENTIAL model yields an average of 0.10975497082852503 per year using 264 days
# This SIMPLE model yields an average of 0.10007604670419146 per year using 265 days
# This EXPONENTIAL model yields an average of 0.10948145825061029 per year using 265 days
# This SIMPLE model yields an average of 0.10012561051241464 per year using 266 days
# This EXPONENTIAL model yields an average of 0.11131867524991712 per year using 266 days
# This SIMPLE model yields an average of 0.10012561051241509 per year using 267 days
# This EXPONENTIAL model yields an average of 0.107034737536289 per year using 267 days
# This SIMPLE model yields an average of 0.10056747277300304 per year using 268 days
# This EXPONENTIAL model yields an average of 0.10417557777254349 per year using 268 days
# This SIMPLE model yields an average of 0.10056747277300415 per year using 269 days
# This EXPONENTIAL model yields an average of 0.10809837322466676 per year using 269 days
# This SIMPLE model yields an average of 0.10056747277300349 per year using 270 days
# This EXPONENTIAL model yields an average of 0.10143189237388373 per year using 270 days
# This SIMPLE model yields an average of 0.1006662782279577 per year using 271 days
# This EXPONENTIAL model yields an average of 0.09601718566628237 per year using 271 days
# This SIMPLE model yields an average of 0.10121536700377409 per year using 272 days
# This EXPONENTIAL model yields an average of 0.09846422862455628 per year using 272 days
# This SIMPLE model yields an average of 0.1011158152101328 per year using 273 days
# This EXPONENTIAL model yields an average of 0.09726535578016726 per year using 273 days
# This SIMPLE model yields an average of 0.10119100089981159 per year using 274 days
# This EXPONENTIAL model yields an average of 0.0959717766167627 per year using 274 days
# This SIMPLE model yields an average of 0.10122510218183689 per year using 275 days
# This EXPONENTIAL model yields an average of 0.09842004270505655 per year using 275 days
# This SIMPLE model yields an average of 0.09948576845806922 per year using 276 days
# This EXPONENTIAL model yields an average of 0.10014342390983333 per year using 276 days
# This SIMPLE model yields an average of 0.09803120051534009 per year using 277 days
# This EXPONENTIAL model yields an average of 0.09829071239853837 per year using 277 days
# This SIMPLE model yields an average of 0.09875622691592278 per year using 278 days
# This EXPONENTIAL model yields an average of 0.09851407865910655 per year using 278 days
# This SIMPLE model yields an average of 0.09812710652394463 per year using 279 days
# This EXPONENTIAL model yields an average of 0.09622270338618222 per year using 279 days
# This SIMPLE model yields an average of 0.0997003555888516 per year using 280 days
# This EXPONENTIAL model yields an average of 0.0962234301731415 per year using 280 days
# This SIMPLE model yields an average of 0.10190470903295168 per year using 281 days
# This EXPONENTIAL model yields an average of 0.09392247258752717 per year using 281 days
# This SIMPLE model yields an average of 0.10108375603746245 per year using 282 days
# This EXPONENTIAL model yields an average of 0.09177540925484085 per year using 282 days
# This SIMPLE model yields an average of 0.10148974063245597 per year using 283 days
# This EXPONENTIAL model yields an average of 0.09146113784834986 per year using 283 days
# This SIMPLE model yields an average of 0.10171967481288613 per year using 284 days
# This EXPONENTIAL model yields an average of 0.0901553934682 per year using 284 days
# This SIMPLE model yields an average of 0.09917440588265536 per year using 285 days
# This EXPONENTIAL model yields an average of 0.09058177333003381 per year using 285 days
# This SIMPLE model yields an average of 0.09873046172706745 per year using 286 days
# This EXPONENTIAL model yields an average of 0.09037055027832519 per year using 286 days
# This SIMPLE model yields an average of 0.10050497003077563 per year using 287 days
# This EXPONENTIAL model yields an average of 0.09116386904285867 per year using 287 days
# This SIMPLE model yields an average of 0.1003265705316454 per year using 288 days
# This EXPONENTIAL model yields an average of 0.09389385604355183 per year using 288 days
# This SIMPLE model yields an average of 0.1025941090499165 per year using 289 days
# This EXPONENTIAL model yields an average of 0.09563991917697878 per year using 289 days
# This SIMPLE model yields an average of 0.10217015350356706 per year using 290 days
# This EXPONENTIAL model yields an average of 0.09873760270233012 per year using 290 days
# This SIMPLE model yields an average of 0.10162058865143808 per year using 291 days
# This EXPONENTIAL model yields an average of 0.09873760270233012 per year using 291 days
# This SIMPLE model yields an average of 0.10252466590052789 per year using 292 days
# This EXPONENTIAL model yields an average of 0.09857965631125132 per year using 292 days
# This SIMPLE model yields an average of 0.10252466590052767 per year using 293 days
# This EXPONENTIAL model yields an average of 0.09857965631125132 per year using 293 days
# This SIMPLE model yields an average of 0.10110783718999405 per year using 294 days
# This EXPONENTIAL model yields an average of 0.09857965631125132 per year using 294 days
# This SIMPLE model yields an average of 0.10284973694865629 per year using 295 days
# This EXPONENTIAL model yields an average of 0.10023247938496493 per year using 295 days
# This SIMPLE model yields an average of 0.10308628862153624 per year using 296 days
# This EXPONENTIAL model yields an average of 0.09998471090749428 per year using 296 days
# This SIMPLE model yields an average of 0.10209497918811561 per year using 297 days
# This EXPONENTIAL model yields an average of 0.09998471090749428 per year using 297 days
# This SIMPLE model yields an average of 0.10206119034568673 per year using 298 days
# This EXPONENTIAL model yields an average of 0.09998471090749428 per year using 298 days
# This SIMPLE model yields an average of 0.10206119034568695 per year using 299 days
# This EXPONENTIAL model yields an average of 0.09998471090749428 per year using 299 days
# This SIMPLE model yields an average of 0.10036341245005209 per year using 300 days
# This EXPONENTIAL model yields an average of 0.09998471090749428 per year using 300 days

# %%
print('Buy and hold average return is', spx_average_return, 'per year')
out_df1 = pd.DataFrame(output_to_csv1, columns=['SMA', 'average_return'])
out_df2 = pd.DataFrame(output_to_csv2, columns=['EMA', 'average_return'])
# Out:
# Buy and hold average return is 0.1032266648282163 per year

# %%
#find best simple moving average
max_simple_return = 0
max_simple_days = 0
for key in simple_returns_dict:
    if simple_returns_dict[key] > max_simple_return:
        max_simple_return = simple_returns_dict[key]
        max_simple_days = key
    else:
        max_simple_return = max_simple_return
        max_simple_days = max_simple_days
print('The best SIMPLE MOVING AVERAGE return is', max_simple_return, 'which uses', max_simple_days, 'simple moving average days')
# Out:
# The best SIMPLE MOVING AVERAGE return is 0.13046141256683108 which uses 3 simple moving average days

# %%
#find best exponential moving average
max_exponential_return = 0
max_exponential_days = 0
for key in exponential_returns_dict:
    if exponential_returns_dict[key] > max_exponential_return:
        max_exponential_return = exponential_returns_dict[key]
        max_exponential_days = key
    else:
        max_exponential_return = max_exponential_return
        max_exponential_days = max_exponential_days
print('The best EXPONENTIAL MOVING AVERAGE return is', max_exponential_return, 'which uses', max_exponential_days, 'exponential moving average days')
# Out:
# The best EXPONENTIAL MOVING AVERAGE return is 0.13388581480508788 which uses 3 exponential moving average days

# %%
print(df)
# Out:
#             date        price       dix           gex  Pct Change  \
# 0     2011-05-02  1361.219971  0.378842  1.897313e+09         NaN
# 1     2011-05-03  1356.619995  0.383411  1.859731e+09   -0.003379
# 2     2011-05-04  1347.319946  0.392122  1.717764e+09   -0.006855
# 3     2011-05-05  1335.099976  0.405457  1.361864e+09   -0.009070
# 4     2011-05-06  1340.199951  0.418649  1.490329e+09    0.003820
# ...          ...          ...       ...           ...         ...
# 2250  2020-04-13  2761.630000  0.493960  3.422978e+09   -0.010105
# 2251  2020-04-14  2846.060000  0.477697  5.900188e+09    0.030573
# 2252  2020-04-15  2783.360000  0.511512  5.008143e+09   -0.022030
# 2253  2020-04-16  2799.550000  0.504736  6.412034e+09    0.005817
# 2254  2020-04-17  2874.560000  0.463644  1.907158e+09    0.026794
#
#       Simple Moving Average  Exponential Moving Average  Criteria  Criteria 2  \
# 0                       NaN                     0.37884     False       False
# 1                       NaN                     0.37887     False       False
# 2                       NaN                     0.37896     False       False
# 3                       NaN                     0.37914     False       False
# 4                       NaN                     0.37940     False       False
# ...                     ...                         ...       ...         ...
# 2250                0.42377                     0.42419      True        True
# 2251                0.42393                     0.42455      True        True
# 2252                0.42419                     0.42513      True        True
# 2253                0.42441                     0.42566      True        True
# 2254                0.42445                     0.42591      True        True
#
#       Buy and Hold Simple Model Exponential Model
# 0              NaN          NaN               NaN
# 1        99.662070          100               100
# 2        98.978855          100               100
# 3        98.081133          100               100
# 4        98.455796          100               100
# ...            ...          ...               ...
# 2250    202.879039      200.118           222.545
# 2251    209.081564      206.236           229.349
# 2252    204.475401      201.692           224.296
# 2253    205.664776      202.865           225.601
# 2254    211.175274      208.301           231.645
#
# [2255 rows x 12 columns]

# %%
out_df1.to_csv('DIXgreatersmatest.csv')
out_df2.to_csv('DIXgreaterematest.csv')
